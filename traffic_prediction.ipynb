# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
import tensorflow as tf
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import layers, Sequential, callbacks
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional, Conv1D, MaxPooling1D
from tensorflow.keras.optimizers import SGD, Adam
import math
from sklearn.metrics import mean_squared_error
from tensorflow.keras.optimizers.schedules import ExponentialDecay

for dirname, _, filenames in os.walk('/content'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/traffic.csv
# /content/.config/.last_update_check.json
# /content/.config/gce
# /content/.config/active_config
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/.last_survey_prompt.yaml
# /content/.config/config_sentinel
# /content/.config/default_configs.db
# /content/.config/logs/2024.02.14/14.27.42.995136.log
# /content/.config/logs/2024.02.14/14.27.50.504674.log
# /content/.config/logs/2024.02.14/14.28.00.668277.log
# /content/.config/logs/2024.02.14/14.27.33.851406.log
# /content/.config/logs/2024.02.14/14.27.08.557557.log
# /content/.config/logs/2024.02.14/14.27.59.896912.log
# /content/.config/configurations/config_default
# /content/sample_data/README.md
# /content/sample_data/anscombe.json
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/california_housing_test.csv
# /content/sample_data/mnist_test.csv

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
data=pd.read_csv("/content/traffic.csv")
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
data['DateTime']=pd.to_datetime(data['DateTime'])

data["Year"]=data['DateTime'].dt.year

data["Month"]=data['DateTime'].dt.month

data["Date_no"]=data['DateTime'].dt.day

data["Hour"]=data['DateTime'].dt.hour

data["Day"]= data['DateTime'].dt.strftime("%A")

# %%
data
# Out:
#                  DateTime  Junction  Vehicles           ID  Year  Month  \
# 0     2015-11-01 00:00:00         1        15  20151101001  2015     11
# 1     2015-11-01 01:00:00         1        13  20151101011  2015     11
# 2     2015-11-01 02:00:00         1        10  20151101021  2015     11
# 3     2015-11-01 03:00:00         1         7  20151101031  2015     11
# 4     2015-11-01 04:00:00         1         9  20151101041  2015     11
# ...                   ...       ...       ...          ...   ...    ...
# 48115 2017-06-30 19:00:00         4        11  20170630194  2017      6
# 48116 2017-06-30 20:00:00         4        30  20170630204  2017      6
# 48117 2017-06-30 21:00:00         4        16  20170630214  2017      6
# 48118 2017-06-30 22:00:00         4        22  20170630224  2017      6
# 48119 2017-06-30 23:00:00         4        12  20170630234  2017      6
#
#        Date_no  Hour     Day
# 0            1     0  Sunday
# 1            1     1  Sunday
# 2            1     2  Sunday
# 3            1     3  Sunday
# 4            1     4  Sunday
# ...        ...   ...     ...
# 48115       30    19  Friday
# 48116       30    20  Friday
# 48117       30    21  Friday
# 48118       30    22  Friday
# 48119       30    23  Friday
#
# [48120 rows x 9 columns]

# %%
sns.lineplot(x=data['Date_no'],y="Vehicles",data=data,hue='Junction')
# Out:
# <Axes: xlabel='Date_no', ylabel='Vehicles'>

# %%
# data = data[(data['Junction'] == 1)]

# %%
data
# Out:
#                  DateTime  Junction  Vehicles           ID  Year  Month  \
# 0     2015-11-01 00:00:00         1        15  20151101001  2015     11
# 1     2015-11-01 01:00:00         1        13  20151101011  2015     11
# 2     2015-11-01 02:00:00         1        10  20151101021  2015     11
# 3     2015-11-01 03:00:00         1         7  20151101031  2015     11
# 4     2015-11-01 04:00:00         1         9  20151101041  2015     11
# ...                   ...       ...       ...          ...   ...    ...
# 48115 2017-06-30 19:00:00         4        11  20170630194  2017      6
# 48116 2017-06-30 20:00:00         4        30  20170630204  2017      6
# 48117 2017-06-30 21:00:00         4        16  20170630214  2017      6
# 48118 2017-06-30 22:00:00         4        22  20170630224  2017      6
# 48119 2017-06-30 23:00:00         4        12  20170630234  2017      6
#
#        Date_no  Hour     Day
# 0            1     0  Sunday
# 1            1     1  Sunday
# 2            1     2  Sunday
# 3            1     3  Sunday
# 4            1     4  Sunday
# ...        ...   ...     ...
# 48115       30    19  Friday
# 48116       30    20  Friday
# 48117       30    21  Friday
# 48118       30    22  Friday
# 48119       30    23  Friday
#
# [48120 rows x 9 columns]

# %%
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %%
df_N, av, std = Normalize(data, "Vehicles")
Diff = Difference(df_N, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N = df_N[24*7:]
df_N.columns = ["Norm"]
df_N["Diff"]= Diff
# Out:
# <ipython-input-10-25558da084e5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_N["Diff"]= Diff

# %%
df = df_N["Diff"].dropna()
df = df.to_frame()

# %%
df.head()
# Out:
#          Diff
# 168 -0.096385
# 169  0.144578
# 170  0.048193
# 171  0.048193
# 172  0.048193

# %%
df.shape
# Out:
# (47952, 1)

# %%
def Split_data(df):
    training_size = int(len(df)*0.80)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len]
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test

df_train, df_test = Split_data(df)

# %%
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

X_train, y_train = TnF(df_train)
X_test, y_test = TnF(df_test)
X_train, X_test = FeatureFixShape(X_train, X_test)

# %%
from sklearn.metrics import mean_absolute_error

lr_schedule = ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=10000,
    decay_rate=0.9)

def MLP_model(X_Train, y_Train, X_Test, y_Test):
    X_Train = np.squeeze(X_Train)  # This line removes the unnecessary dimension
    X_Test = np.squeeze(X_Test)    # Do the same for the test data
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True)
    model = Sequential()
    model.add(Dense(100, activation='relu', input_dim=X_Train.shape[1]))
    model.add(Dropout(0.2))
    model.add(Dense(20, activation='relu', input_dim=X_Train.shape[1]))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer=SGD(learning_rate=lr_schedule, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train, y_Train, validation_data=(X_test, y_test), epochs=50, batch_size=120, callbacks=[early_stopping])
    pred_MLP = model.predict(X_Test)
    return pred_MLP

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

def MAE_Value(test,predicted):
    mae = mean_absolute_error(test, predicted)
    print("The MAE is {}.".format(mae))
    return mae

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5))
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted,label="Predicted Values")
    plt.title("Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %%
Pred_MLP = MLP_model(X_train,y_train,X_test, y_test)
# Out:
# Epoch 1/50
# 320/320 [==============================] - 6s 6ms/step - loss: 0.0914 - val_loss: 0.1128
# Epoch 2/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0690 - val_loss: 0.1049
# Epoch 3/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0659 - val_loss: 0.1008
# Epoch 4/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0636 - val_loss: 0.0985
# Epoch 5/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0654 - val_loss: 0.0986
# Epoch 6/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0637 - val_loss: 0.1004
# Epoch 7/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0617 - val_loss: 0.0967
# Epoch 8/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0621 - val_loss: 0.0961
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0603 - val_loss: 0.0952
# Epoch 10/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0608 - val_loss: 0.0952
# Epoch 11/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0588 - val_loss: 0.0964
# Epoch 12/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0598 - val_loss: 0.0945
# Epoch 13/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0595 - val_loss: 0.0947
# Epoch 14/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0588 - val_loss: 0.0942
# Epoch 15/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0588 - val_loss: 0.0943
# Epoch 16/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0585 - val_loss: 0.0945
# Epoch 17/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0587 - val_loss: 0.0944
# Epoch 18/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0586 - val_loss: 0.0945
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0593 - val_loss: 0.0940
# Epoch 20/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0588 - val_loss: 0.0940
# Epoch 21/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0580 - val_loss: 0.0937
# Epoch 22/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0584 - val_loss: 0.0940
# Epoch 23/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0574 - val_loss: 0.0940
# Epoch 24/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0576 - val_loss: 0.0934
# Epoch 25/50
# 320/320 [==============================] - 1s 4ms/step - loss: 0.0575 - val_loss: 0.0932
# Epoch 26/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0560 - val_loss: 0.0936
# Epoch 27/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0570 - val_loss: 0.0933
# Epoch 28/50
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0581 - val_loss: 0.0933
# Epoch 29/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0578 - val_loss: 0.0940
# 299/299 [==============================] - 1s 2ms/step

# %%
colors = ["#6D91A1","#74B3CE1","#536D7A","#3E535B"]

# %%
RMSE_MLP = RMSE_Value(y_test, Pred_MLP)
MAE_MLP = MAE_Value(y_test, Pred_MLP)
PredictionsPlot(y_test, Pred_MLP, 0)
# Out:
# The root mean squared error is 0.3065476616366302.
# The MAE is 0.16750666695838826.

# %%
def inverse_difference(last_ob, value):
    inversed = value + last_ob
    return inversed

def Sub_Plots(df_1, df_2,title,m):
    fig, axes = plt.subplots(1, 2, figsize=(18,4), sharey=True)
    fig.suptitle(title)

    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[m])
    axes[0].set(ylabel ="Prediction")

    pl_2=sns.lineplot(ax=axes[1],data=df_2["Vehicles"],color="#3E535B")
    axes[1].set(ylabel ="Original")

# %%
recover = df_N.Norm[-9560:-1].to_frame()
recover["Pred"]= globals()[f"Pred_MLP"]
Transform_reverssed = inverse_difference(recover.Norm, recover.Pred).to_frame()
Transform_reverssed.columns = ["Pred_Normed"]
Final_Pred = (Transform_reverssed.values* std) + av
Transform_reverssed["Pred_Final"] = Final_Pred
Sub_Plots(Transform_reverssed["Pred_Final"], data[-2854:-1],"Predictions And Originals For Junction 1", 0)

# %%
def GRU_model(X_Train, y_Train, X_Test, y_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True)
    #callback delta 0.01 may interrupt the learning.

    #The GRU model
    model = Sequential()
    model.add(GRU(units=100, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=20, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))

    #Compiling the model
    model.compile(optimizer=SGD(learning_rate=lr_schedule, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, validation_data=(X_Test, y_Test), epochs=50, batch_size=120,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

# %%
def LSTM_model(X_Train, y_Train, X_Test, y_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True)

    #The LSTM model
    model = Sequential()
    model.add(LSTM(units=100, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(LSTM(units=20, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))

    #Compiling the model
    model.compile(optimizer=SGD(learning_rate=lr_schedule, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, validation_data=(X_Test, y_Test), epochs=50, batch_size=120,callbacks=[early_stopping])
    pred_LSTM = model.predict(X_Test)
    return pred_LSTM

# %%
# %time
Pred_GRU = GRU_model(X_train,y_train,X_test,y_test)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.87 µs
# Epoch 1/50
# 320/320 [==============================] - 7s 11ms/step - loss: 0.0750 - val_loss: 0.1174
# Epoch 2/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0658 - val_loss: 0.1098
# Epoch 3/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0631 - val_loss: 0.1077
# Epoch 4/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0622 - val_loss: 0.1084
# Epoch 5/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0606 - val_loss: 0.1056
# Epoch 6/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0604 - val_loss: 0.1036
# Epoch 7/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0594 - val_loss: 0.1025
# Epoch 8/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0590 - val_loss: 0.1030
# Epoch 9/50
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0587 - val_loss: 0.1024
# Epoch 10/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0596 - val_loss: 0.1012
# Epoch 11/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0593 - val_loss: 0.1013
# Epoch 12/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0591 - val_loss: 0.1013
# Epoch 13/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0584 - val_loss: 0.1008
# Epoch 14/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0593 - val_loss: 0.1049
# Epoch 15/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0591 - val_loss: 0.1015
# Epoch 16/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0592 - val_loss: 0.1014
# Epoch 17/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0583 - val_loss: 0.1002
# Epoch 18/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0588 - val_loss: 0.1008
# Epoch 19/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0585 - val_loss: 0.1006
# Epoch 20/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0584 - val_loss: 0.1003
# Epoch 21/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0578 - val_loss: 0.1003
# Epoch 22/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0578 - val_loss: 0.1014
# Epoch 23/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0584 - val_loss: 0.1003
# Epoch 24/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0582 - val_loss: 0.0998
# Epoch 25/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0580 - val_loss: 0.0999
# Epoch 26/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0586 - val_loss: 0.1004
# Epoch 27/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0586 - val_loss: 0.0999
# 299/299 [==============================] - 1s 3ms/step

# %%
RMSE_GRU = RMSE_Value(y_test, Pred_GRU)
MAE_GRU = MAE_Value(y_test, Pred_GRU)
PredictionsPlot(y_test, Pred_GRU, 0)
# Out:
# The root mean squared error is 0.31655344979355554.
# The MAE is 0.17495673699943695.

# %%
Pred_LSTM = LSTM_model(X_train,y_train,X_test, y_test)
# Out:
# Epoch 1/50
# 320/320 [==============================] - 7s 11ms/step - loss: 0.0881 - val_loss: 0.1437
# Epoch 2/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0764 - val_loss: 0.1353
# Epoch 3/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0712 - val_loss: 0.1266
# Epoch 4/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0675 - val_loss: 0.1212
# Epoch 5/50
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0662 - val_loss: 0.1188
# Epoch 6/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0646 - val_loss: 0.1164
# Epoch 7/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0635 - val_loss: 0.1140
# Epoch 8/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0626 - val_loss: 0.1128
# Epoch 9/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0614 - val_loss: 0.1123
# Epoch 10/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0613 - val_loss: 0.1097
# Epoch 11/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0618 - val_loss: 0.1094
# Epoch 12/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0608 - val_loss: 0.1086
# Epoch 13/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0596 - val_loss: 0.1073
# Epoch 14/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0607 - val_loss: 0.1068
# Epoch 15/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0597 - val_loss: 0.1067
# Epoch 16/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0587 - val_loss: 0.1059
# Epoch 17/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0593 - val_loss: 0.1055
# Epoch 18/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0588 - val_loss: 0.1052
# Epoch 19/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0591 - val_loss: 0.1044
# Epoch 20/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0586 - val_loss: 0.1046
# Epoch 21/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0585 - val_loss: 0.1039
# Epoch 22/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0587 - val_loss: 0.1037
# Epoch 23/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0582 - val_loss: 0.1036
# Epoch 24/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0582 - val_loss: 0.1031
# Epoch 25/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0587 - val_loss: 0.1030
# Epoch 26/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0582 - val_loss: 0.1034
# Epoch 27/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0583 - val_loss: 0.1040
# Epoch 28/50
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0582 - val_loss: 0.1023
# Epoch 29/50
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0581 - val_loss: 0.1021
# Epoch 30/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0576 - val_loss: 0.1021
# Epoch 31/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0580 - val_loss: 0.1015
# Epoch 32/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0577 - val_loss: 0.1013
# Epoch 33/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0574 - val_loss: 0.1014
# Epoch 34/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0576 - val_loss: 0.1011
# Epoch 35/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0576 - val_loss: 0.1012
# Epoch 36/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0579 - val_loss: 0.1011
# Epoch 37/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0580 - val_loss: 0.1009
# Epoch 38/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0574 - val_loss: 0.1016
# Epoch 39/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0576 - val_loss: 0.1008
# Epoch 40/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0576 - val_loss: 0.1005
# Epoch 41/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0579 - val_loss: 0.1004
# Epoch 42/50
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0574 - val_loss: 0.1001
# Epoch 43/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0579 - val_loss: 0.1001
# Epoch 44/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0574 - val_loss: 0.1001
# Epoch 45/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0574 - val_loss: 0.0999
# Epoch 46/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0574 - val_loss: 0.1007
# Epoch 47/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0568 - val_loss: 0.1002
# Epoch 48/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0574 - val_loss: 0.0998
# Epoch 49/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0572 - val_loss: 0.0995
# Epoch 50/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0573 - val_loss: 0.0999
# 299/299 [==============================] - 2s 3ms/step

# %%
RMSE_LSTM = RMSE_Value(y_test, Pred_LSTM)
MAE_LSTM = MAE_Value(y_test, Pred_LSTM)
PredictionsPlot(y_test, Pred_LSTM, 0)
# Out:
# The root mean squared error is 0.3160891581156699.
# The MAE is 0.17433751152439625.
